# %% [markdown]
# Training script for kernel-KL divergence.
#
# $ \mathcal{L}_{KL} = D_{KL}(\Sigma_{p_\theta} || \,\Sigma_\pi) = \text{Tr}\left( \Sigma_{p_\theta} \, \text{log}( \Sigma_{p_\theta} - \Sigma_\pi  )  \right), $
#
# where
#
# $\Sigma_p = \sum_{x \in \mathcal{X}} \phi(x) \phi(x)^* p(x) $
#
# is the kernel covariance embedding with feature map
#
# $ \phi(x) = \phi_\eta(x) = \text{diag}(\eta)^{\frac{1}{2}} \begin{pmatrix} x \\ 1 \end{pmatrix} .$

# %%
import numpy as np
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, transpile, Aer, execute
from qiskit.visualization import plot_histogram
from qiskit.circuit.library import IQP
from qiskit.circuit import ParameterVector

import pennylane as qml

from src import QCIBM_utilities as ut

# %%
nq = 3
#alpha_init = np.array([[1,0],[0.1,0.3]])
#Gamma_init = np.array([1,1])
#Delta_init = np.array([0.5, 0.2])
#Sigma_init = np.array([0,0.1])
#theta_init = ut.compose_params(alpha_init, Gamma_init, Delta_init, Sigma_init)

rng = np.random.default_rng(27031995)

theta_init = np.array((np.pi) * rng.random(int(nq*(nq+3)/2)))
theta = ParameterVector('θ', int(nq*(nq+3)/2))

# %%
# Sample hyperparams
p_pi = 0.6
n_train = 500
sampleshots = 500

# %%
kernel_params = np.ones(nq+1)*(1/(nq+1)) # eta (uniform)

# %%
backend = Aer.get_backend('qasm_simulator')

# %%
alpha, Gamma, Delta, Sigma = ut.decompose_params(theta, nq)
qc = ut.QCIBM(alpha, Gamma, Delta, Sigma, nq)
qc = transpile(qc, backend)

# %%
# Samples modes
T = 3
ps = 0.4
pi_modes = np.zeros((T,nq)) 
for t in range(T):
    for i in range(nq):
        pi_modes[t,i] = rng.binomial(1, ps)
print('modes = ', pi_modes)
# Out:
# modes =  [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
ysamples, pi_vec = ut.sample_target_pdf(n_train, pi_modes, p_pi)
xsamples, phat = ut.sample_circuit( backend, sampleshots, qc.bind_parameters({theta: theta_init}))

# %%
KL_grad = ut.KL_Hypercube_grad(qc, theta, theta_init, xsamples, ysamples, backend, kernel_params)
print(KL_grad)
# Out:
# [ -28.28354226  -25.95786669   -2.99826505  -14.64304903  -53.5030389
#  -128.16915905   16.16735683  -19.09452404  -17.6670734 ]

# %%
def L_wrapper(theta_, xsamples):
    L = ut.KL_Hypercube_Loss(xsamples, ysamples, kernel_params)
    return(L)

def grad_wrapper(theta_, xsamples, ysamples):
    nablaL = ut.KL_Hypercube_grad(qc, theta, theta_, xsamples, ysamples, backend, kernel_params)
    return(nablaL)

# %%
eta = 0.005 #stepsize
theta_opt, KL_history, TV_history = ut.adam(L_wrapper, grad_wrapper, theta, theta_init, backend, qc, sampleshots, ysamples, batch_size = 250, p_target = pi_vec, tol = -1, maxiter = 200, alpha = eta)
print('θ_opt = ', theta_opt)
print('min Loss = ', KL_history[-1])
# Out:
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999971
# 1  row sum =  1.0000000000000044
# 2  row sum =  0.9999999999999991
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.9999999999999962
# 1  column sum =  1.0000000000000062
# 2  column sum =  0.9999999999999973
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  1
#  - Current Loss =  514.3364773633623
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000013
# 1  row sum =  0.9999999999999999
# 2  row sum =  0.9999999999999998
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.0000000000000016
# 2  column sum =  0.9999999999999997
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  2
#  - Current Loss =  597.161039068983
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000002
# 1  row sum =  1.0000000000000004
# 2  row sum =  1.0
# 3  row sum =  0.9999999999999994
# 0  column sum =  0.9999999999999994
# 1  column sum =  1.0000000000000009
# 2  column sum =  0.9999999999999996
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  3
#  - Current Loss =  100.88803264612443
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999989
# 1  row sum =  0.9999999999999994
# 2  row sum =  1.0000000000000007
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999981
# 1  column sum =  1.000000000000001
# 2  column sum =  0.9999999999999998
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  4
#  - Current Loss =  49.72809432987083
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999986
# 1  row sum =  0.9999999999999999
# 2  row sum =  1.0000000000000004
# 3  row sum =  1.0000000000000002
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000016
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  5
#  - Current Loss =  60.885934383717085
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999999
# 1  row sum =  1.000000000000001
# 2  row sum =  0.9999999999999987
# 3  row sum =  1.0000000000000002
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999988
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  6
#  - Current Loss =  453.66508454207917
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0
# 1  row sum =  1.0000000000000016
# 2  row sum =  0.9999999999999993
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.9999999999999988
# 1  column sum =  1.000000000000002
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  7
#  - Current Loss =  452.0965630037174
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0
# 1  row sum =  1.000000000000003
# 2  row sum =  0.9999999999999977
# 3  row sum =  0.9999999999999996
# 0  column sum =  0.9999999999999974
# 1  column sum =  1.0000000000000038
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  8
#  - Current Loss =  447.08629865685964
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999994
# 1  row sum =  1.0000000000000036
# 2  row sum =  0.9999999999999973
# 3  row sum =  0.9999999999999997
# 0  column sum =  0.9999999999999971
# 1  column sum =  1.0000000000000044
# 2  column sum =  0.9999999999999978
# 3  column sum =  1.0000000000000009
#  -- Adam Optimization -- Step t =  9
#  - Current Loss =  453.5541949183789
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999993
# 1  row sum =  1.0000000000000018
# 2  row sum =  0.9999999999999987
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999988
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999988
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  10
#  - Current Loss =  452.9235438581454
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000002
# 1  row sum =  1.000000000000001
# 2  row sum =  0.9999999999999991
# 3  row sum =  0.9999999999999999
# 0  column sum =  0.9999999999999981
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999986
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  11
#  - Current Loss =  455.5322963090946
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000002
# 1  row sum =  1.000000000000001
# 2  row sum =  0.9999999999999984
# 3  row sum =  1.0000000000000002
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999992
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  12
#  - Current Loss =  457.7300012222631
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0
# 1  row sum =  1.0000000000000013
# 2  row sum =  0.9999999999999989
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999988
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  13
#  - Current Loss =  457.2013778709321
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999998
# 1  row sum =  1.0000000000000016
# 2  row sum =  0.9999999999999986
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999977
# 1  column sum =  1.0000000000000038
# 2  column sum =  0.9999999999999981
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  14
#  - Current Loss =  456.8228828428813
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000002
# 1  row sum =  1.0000000000000004
# 2  row sum =  0.9999999999999991
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.0000000000000018
# 2  column sum =  0.9999999999999993
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  15
#  - Current Loss =  462.85543278229466
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000009
# 1  row sum =  1.0000000000000004
# 2  row sum =  0.9999999999999993
# 3  row sum =  0.9999999999999991
# 0  column sum =  0.9999999999999979
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999996
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  16
#  - Current Loss =  462.53598958895714
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000004
# 1  row sum =  1.0000000000000007
# 2  row sum =  0.9999999999999987
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  17
#  - Current Loss =  467.18344865260485
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000004
# 1  row sum =  1.0000000000000009
# 2  row sum =  0.9999999999999984
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999992
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  18
#  - Current Loss =  464.68433137949705
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999996
# 1  row sum =  1.0000000000000004
# 2  row sum =  0.9999999999999996
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.0000000000000036
# 2  column sum =  0.9999999999999986
# 3  column sum =  0.9999999999999996
#  -- Adam Optimization -- Step t =  19
#  - Current Loss =  81.72520019113722
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999988
# 1  row sum =  1.0000000000000002
# 2  row sum =  1.0000000000000009
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999981
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  20
#  - Current Loss =  84.17377095778352
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999991
# 1  row sum =  1.0000000000000002
# 2  row sum =  1.0000000000000007
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999992
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  21
#  - Current Loss =  82.6845335495143
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.999999999999999
# 1  row sum =  1.0
# 2  row sum =  1.0000000000000009
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  22
#  - Current Loss =  86.5515420556278
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000009
# 1  row sum =  1.0000000000000002
# 2  row sum =  0.9999999999999987
# 3  row sum =  1.0000000000000002
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999996
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  23
#  - Current Loss =  477.6147085056623
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999986
# 1  row sum =  1.0000000000000002
# 2  row sum =  1.0000000000000007
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999983
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999997
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  24
#  - Current Loss =  86.07236254972872
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.999999999999999
# 1  row sum =  1.0
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.0000000000000016
# 0  column sum =  0.9999999999999983
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999993
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  25
#  - Current Loss =  85.44097850102594
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999994
# 1  row sum =  0.9999999999999997
# 2  row sum =  1.0000000000000004
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999989
# 1  column sum =  1.0000000000000018
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  26
#  - Current Loss =  85.15889508051919
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999988
# 1  row sum =  0.9999999999999997
# 2  row sum =  1.0000000000000009
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  27
#  - Current Loss =  85.63875140005507
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  0.9999999999999998
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.000000000000001
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999992
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  28
#  - Current Loss =  84.51389037693139
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999992
# 1  row sum =  0.9999999999999996
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.0000000000000002
# 0  column sum =  0.9999999999999989
# 1  column sum =  1.0000000000000013
# 2  column sum =  0.9999999999999988
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  29
#  - Current Loss =  85.32697800204937
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999986
# 1  row sum =  0.9999999999999994
# 2  row sum =  1.0000000000000004
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999983
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  30
#  - Current Loss =  87.32031475589542
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999991
# 1  row sum =  0.9999999999999997
# 2  row sum =  1.0000000000000004
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999988
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  31
#  - Current Loss =  89.00814553547093
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999988
# 1  row sum =  0.9999999999999998
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.0000000000000013
# 0  column sum =  0.9999999999999981
# 1  column sum =  1.000000000000003
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  32
#  - Current Loss =  90.88634676953279
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999982
# 1  row sum =  0.9999999999999998
# 2  row sum =  1.0000000000000009
# 3  row sum =  1.0000000000000013
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999992
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  33
#  - Current Loss =  89.83622451001702
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999989
# 1  row sum =  0.9999999999999994
# 2  row sum =  0.9999999999999998
# 3  row sum =  1.0000000000000022
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.0000000000000036
# 2  column sum =  0.9999999999999987
# 3  column sum =  0.9999999999999998
#  -- Adam Optimization -- Step t =  34
#  - Current Loss =  91.23496043005002
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  0.9999999999999999
# 2  row sum =  0.9999999999999999
# 3  row sum =  1.0000000000000016
# 0  column sum =  0.9999999999999983
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999989
# 3  column sum =  0.9999999999999998
#  -- Adam Optimization -- Step t =  35
#  - Current Loss =  88.80370486532888
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999979
# 1  row sum =  0.9999999999999998
# 2  row sum =  1.0000000000000009
# 3  row sum =  1.0000000000000013
# 0  column sum =  0.9999999999999977
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999993
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  36
#  - Current Loss =  87.24939814415734
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999992
# 1  row sum =  0.9999999999999996
# 2  row sum =  0.9999999999999996
# 3  row sum =  1.0000000000000013
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999984
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  37
#  - Current Loss =  86.7760277659495
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999983
# 1  row sum =  0.9999999999999997
# 2  row sum =  1.0
# 3  row sum =  1.0000000000000016
# 0  column sum =  0.9999999999999979
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  38
#  - Current Loss =  84.81674635406284
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  1.0
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.000000000000001
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  39
#  - Current Loss =  82.42373168526342
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999984
# 1  row sum =  0.9999999999999999
# 2  row sum =  1.0000000000000009
# 3  row sum =  1.0000000000000013
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999992
# 3  column sum =  1.000000000000001
#  -- Adam Optimization -- Step t =  40
#  - Current Loss =  80.80524605054643
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999983
# 1  row sum =  1.0000000000000002
# 2  row sum =  0.9999999999999998
# 3  row sum =  1.0000000000000016
# 0  column sum =  0.9999999999999979
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  41
#  - Current Loss =  79.41613905100667
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999989
# 1  row sum =  1.0
# 2  row sum =  1.0
# 3  row sum =  1.0000000000000013
# 0  column sum =  0.9999999999999986
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999986
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  42
#  - Current Loss =  78.26934694305282
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999994
# 1  row sum =  0.9999999999999999
# 2  row sum =  0.9999999999999993
# 3  row sum =  1.0000000000000013
# 0  column sum =  0.9999999999999992
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999988
# 3  column sum =  0.9999999999999993
#  -- Adam Optimization -- Step t =  43
#  - Current Loss =  77.92758239690738
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999998
# 1  row sum =  0.9999999999999998
# 2  row sum =  0.9999999999999991
# 3  row sum =  1.000000000000001
# 0  column sum =  0.9999999999999994
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999982
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  44
#  - Current Loss =  75.5210516017462
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999984
# 1  row sum =  1.0000000000000004
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999983
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999996
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  45
#  - Current Loss =  74.686725806195
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  0.9999999999999994
# 2  row sum =  1.0000000000000004
# 3  row sum =  1.0000000000000013
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.0000000000000018
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  46
#  - Current Loss =  72.841838520181
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999989
# 1  row sum =  0.9999999999999998
# 2  row sum =  1.0000000000000007
# 3  row sum =  1.000000000000001
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000018
# 2  column sum =  0.9999999999999992
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  47
#  - Current Loss =  72.17616519841408
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999994
# 1  row sum =  1.0
# 2  row sum =  0.9999999999999996
# 3  row sum =  1.0000000000000016
# 0  column sum =  0.999999999999999
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  48
#  - Current Loss =  71.74437709891208
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.999999999999998
# 1  row sum =  1.0
# 2  row sum =  0.9999999999999996
# 3  row sum =  1.0000000000000018
# 0  column sum =  0.9999999999999974
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  49
#  - Current Loss =  70.36856400567194
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999997
# 1  row sum =  1.0000000000000004
# 2  row sum =  0.9999999999999987
# 3  row sum =  1.0000000000000018
# 0  column sum =  0.999999999999999
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  50
#  - Current Loss =  69.77111802295144
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999982
# 1  row sum =  1.0000000000000004
# 2  row sum =  0.9999999999999998
# 3  row sum =  1.000000000000001
# 0  column sum =  0.9999999999999977
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  51
#  - Current Loss =  68.95963400659707
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999989
# 1  row sum =  1.0000000000000002
# 2  row sum =  1.0
# 3  row sum =  1.000000000000001
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  52
#  - Current Loss =  68.19208387465687
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999978
# 1  row sum =  1.0000000000000004
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.0000000000000018
# 0  column sum =  0.9999999999999973
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0000000000000009
#  -- Adam Optimization -- Step t =  53
#  - Current Loss =  66.83477178848693
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999984
# 1  row sum =  1.0
# 2  row sum =  0.9999999999999999
# 3  row sum =  1.000000000000001
# 0  column sum =  0.9999999999999986
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999984
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  54
#  - Current Loss =  66.37088725109265
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999978
# 1  row sum =  0.9999999999999997
# 2  row sum =  1.0000000000000004
# 3  row sum =  1.0000000000000016
# 0  column sum =  0.9999999999999977
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999989
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  55
#  - Current Loss =  65.8882953369307
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999984
# 1  row sum =  1.0000000000000004
# 2  row sum =  0.9999999999999998
# 3  row sum =  1.0000000000000016
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  56
#  - Current Loss =  64.6390902525659
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999982
# 1  row sum =  1.0000000000000002
# 2  row sum =  0.9999999999999998
# 3  row sum =  1.0000000000000013
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999988
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  57
#  - Current Loss =  62.966740414675314
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999992
# 1  row sum =  0.9999999999999996
# 2  row sum =  1.0000000000000018
# 3  row sum =  0.9999999999999991
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999988
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  58
#  - Current Loss =  118.49446216575302
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000013
# 1  row sum =  0.9999999999999993
# 2  row sum =  1.0000000000000004
# 3  row sum =  0.9999999999999994
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.0000000000000018
# 2  column sum =  0.9999999999999993
# 3  column sum =  1.0000000000000009
#  -- Adam Optimization -- Step t =  59
#  - Current Loss =  474.12498752129113
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999994
# 1  row sum =  0.9999999999999996
# 2  row sum =  1.0000000000000013
# 3  row sum =  0.9999999999999991
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999988
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  60
#  - Current Loss =  123.71067690779546
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000002
# 1  row sum =  0.9999999999999994
# 2  row sum =  1.0000000000000016
# 3  row sum =  0.9999999999999988
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  61
#  - Current Loss =  128.98550995203595
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  1.0000000000000016
# 2  row sum =  0.9999999999999996
# 3  row sum =  1.0000000000000007
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.0000000000000038
# 2  column sum =  0.999999999999998
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  62
#  - Current Loss =  361.6436062675575
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999993
# 1  row sum =  1.0000000000000004
# 2  row sum =  1.0000000000000004
# 3  row sum =  0.999999999999999
# 0  column sum =  0.9999999999999979
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999992
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  63
#  - Current Loss =  355.9683778160563
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  1.0000000000000009
# 2  row sum =  1.0000000000000004
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.9999999999999976
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  64
#  - Current Loss =  351.07640770891817
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999982
# 1  row sum =  1.000000000000002
# 2  row sum =  0.9999999999999997
# 3  row sum =  1.0000000000000002
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000042
# 2  column sum =  0.9999999999999977
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  65
#  - Current Loss =  349.40999660134094
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  1.0000000000000016
# 2  row sum =  0.9999999999999992
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999974
# 1  column sum =  1.0000000000000038
# 2  column sum =  0.9999999999999982
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  66
#  - Current Loss =  348.6769694036823
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  1.0000000000000016
# 2  row sum =  0.9999999999999992
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999974
# 1  column sum =  1.0000000000000038
# 2  column sum =  0.9999999999999982
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  67
#  - Current Loss =  348.6769694036823
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999991
# 1  row sum =  1.0000000000000007
# 2  row sum =  1.0
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999983
# 1  column sum =  1.0000000000000018
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  68
#  - Current Loss =  347.7535292327332
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999978
# 1  row sum =  1.0000000000000013
# 2  row sum =  1.0000000000000007
# 3  row sum =  0.9999999999999997
# 0  column sum =  0.9999999999999981
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999982
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  69
#  - Current Loss =  348.27040534132993
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.999999999999999
# 1  row sum =  1.0000000000000007
# 2  row sum =  0.9999999999999998
# 3  row sum =  0.9999999999999999
# 0  column sum =  0.9999999999999991
# 1  column sum =  1.0000000000000007
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  70
#  - Current Loss =  347.9673787139757
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  1.0000000000000004
# 2  row sum =  1.0000000000000009
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999989
# 1  column sum =  1.0000000000000013
# 2  column sum =  0.9999999999999993
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  71
#  - Current Loss =  353.8552075153764
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999996
# 1  row sum =  1.0000000000000016
# 2  row sum =  0.9999999999999999
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.0000000000000036
# 2  column sum =  0.9999999999999989
# 3  column sum =  0.9999999999999996
#  -- Adam Optimization -- Step t =  72
#  - Current Loss =  355.3395546141635
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0
# 1  row sum =  1.0000000000000007
# 2  row sum =  1.0
# 3  row sum =  0.9999999999999991
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999996
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  73
#  - Current Loss =  359.11633054364506
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999983
# 1  row sum =  1.000000000000002
# 2  row sum =  0.9999999999999993
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999991
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999978
# 3  column sum =  1.0000000000000009
#  -- Adam Optimization -- Step t =  74
#  - Current Loss =  356.4092250820097
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999986
# 1  row sum =  1.000000000000001
# 2  row sum =  0.9999999999999994
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999982
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  75
#  - Current Loss =  355.47177458815554
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999983
# 1  row sum =  1.0000000000000007
# 2  row sum =  1.0000000000000007
# 3  row sum =  1.0000000000000002
# 0  column sum =  0.9999999999999991
# 1  column sum =  1.0000000000000016
# 2  column sum =  0.9999999999999989
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  76
#  - Current Loss =  353.0629668626241
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999974
# 1  row sum =  1.0000000000000018
# 2  row sum =  1.0000000000000004
# 3  row sum =  0.9999999999999997
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000033
# 2  column sum =  0.9999999999999976
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  77
#  - Current Loss =  352.5708998804257
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.999999999999999
# 1  row sum =  1.0000000000000009
# 2  row sum =  1.0
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000018
# 2  column sum =  0.9999999999999996
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  78
#  - Current Loss =  349.3241880588132
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999974
# 1  row sum =  1.0000000000000024
# 2  row sum =  1.0000000000000002
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000036
# 2  column sum =  0.9999999999999978
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  79
#  - Current Loss =  348.53059115860196
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999997
# 1  row sum =  1.0000000000000016
# 2  row sum =  0.9999999999999994
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.9999999999999981
# 1  column sum =  1.0000000000000033
# 2  column sum =  0.9999999999999988
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  80
#  - Current Loss =  347.6599893071923
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.999999999999997
# 1  row sum =  1.0000000000000009
# 2  row sum =  1.0000000000000018
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999979
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  81
#  - Current Loss =  66.16527253798608
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999976
# 1  row sum =  1.0000000000000007
# 2  row sum =  1.000000000000001
# 3  row sum =  1.0000000000000007
# 0  column sum =  0.9999999999999988
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999984
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  82
#  - Current Loss =  66.02513314891553
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  1.0000000000000013
# 2  row sum =  1.0
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.9999999999999988
# 1  column sum =  1.0000000000000016
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  83
#  - Current Loss =  343.28336054941633
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999979
# 1  row sum =  1.0000000000000016
# 2  row sum =  1.0000000000000007
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.9999999999999993
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999983
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  84
#  - Current Loss =  344.171127066405
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999998
# 1  row sum =  1.0000000000000009
# 2  row sum =  0.9999999999999998
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.9999999999999979
# 1  column sum =  1.0000000000000018
# 2  column sum =  1.0
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  85
#  - Current Loss =  342.9194425608189
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999978
# 1  row sum =  1.0000000000000022
# 2  row sum =  1.0000000000000004
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000036
# 2  column sum =  0.9999999999999978
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  86
#  - Current Loss =  339.8717522045449
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999974
# 1  row sum =  1.0000000000000013
# 2  row sum =  1.0000000000000007
# 3  row sum =  1.0000000000000002
# 0  column sum =  0.9999999999999986
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.999999999999998
# 3  column sum =  1.0000000000000009
#  -- Adam Optimization -- Step t =  87
#  - Current Loss =  339.62051699861763
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  1.0000000000000018
# 2  row sum =  0.9999999999999993
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.000000000000003
# 2  column sum =  0.9999999999999984
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  88
#  - Current Loss =  341.15986967075446
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999989
# 1  row sum =  1.000000000000002
# 2  row sum =  0.9999999999999997
# 3  row sum =  0.9999999999999991
# 0  column sum =  0.999999999999998
# 1  column sum =  1.000000000000003
# 2  column sum =  0.9999999999999987
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  89
#  - Current Loss =  340.90916428771993
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999988
# 1  row sum =  1.000000000000001
# 2  row sum =  1.0000000000000009
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.999999999999999
# 1  column sum =  1.0000000000000013
# 2  column sum =  0.9999999999999996
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  90
#  - Current Loss =  340.1727042555192
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.999999999999999
# 1  row sum =  1.0000000000000007
# 2  row sum =  1.0
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.9999999999999983
# 1  column sum =  1.0000000000000016
# 2  column sum =  0.9999999999999992
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  91
#  - Current Loss =  337.1362289443273
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999998
# 1  row sum =  1.0000000000000002
# 2  row sum =  1.0000000000000004
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999983
# 1  column sum =  1.0000000000000013
# 2  column sum =  0.9999999999999999
# 3  column sum =  1.000000000000001
#  -- Adam Optimization -- Step t =  92
#  - Current Loss =  336.71929564890775
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999979
# 1  row sum =  1.0000000000000018
# 2  row sum =  1.0000000000000007
# 3  row sum =  0.9999999999999999
# 0  column sum =  0.9999999999999983
# 1  column sum =  1.000000000000003
# 2  column sum =  0.9999999999999987
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  93
#  - Current Loss =  334.8861809882694
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999986
# 1  row sum =  1.0000000000000016
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.000000000000003
# 2  column sum =  0.9999999999999989
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  94
#  - Current Loss =  335.53880882493377
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999977
# 1  row sum =  1.0000000000000016
# 2  row sum =  1.0000000000000009
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999989
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  95
#  - Current Loss =  335.3007943853479
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999967
# 1  row sum =  1.0000000000000009
# 2  row sum =  1.0000000000000016
# 3  row sum =  1.0000000000000007
# 0  column sum =  0.9999999999999976
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  96
#  - Current Loss =  70.94179250977322
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0
# 1  row sum =  1.0000000000000002
# 2  row sum =  1.0000000000000007
# 3  row sum =  0.9999999999999991
# 0  column sum =  0.999999999999999
# 1  column sum =  1.0000000000000007
# 2  column sum =  1.0000000000000004
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  97
#  - Current Loss =  331.5430760759266
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999978
# 1  row sum =  1.0000000000000016
# 2  row sum =  0.9999999999999999
# 3  row sum =  1.0000000000000002
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.0000000000000033
# 2  column sum =  0.9999999999999981
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  98
#  - Current Loss =  332.15721791975784
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999996
# 1  row sum =  1.0000000000000007
# 2  row sum =  0.9999999999999992
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999996
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  99
#  - Current Loss =  333.5032689556099
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999971
# 1  row sum =  1.0000000000000022
# 2  row sum =  1.0000000000000007
# 3  row sum =  0.9999999999999999
# 0  column sum =  0.9999999999999991
# 1  column sum =  1.0000000000000033
# 2  column sum =  0.9999999999999976
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  100
#  - Current Loss =  332.375276013978
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999982
# 1  row sum =  1.0000000000000013
# 2  row sum =  0.9999999999999997
# 3  row sum =  1.0000000000000007
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999983
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  101
#  - Current Loss =  329.523518245182
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999967
# 1  row sum =  1.0000000000000024
# 2  row sum =  1.0000000000000009
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.999999999999999
# 1  column sum =  1.0000000000000038
# 2  column sum =  0.9999999999999977
# 3  column sum =  0.9999999999999997
#  -- Adam Optimization -- Step t =  102
#  - Current Loss =  330.22284168093006
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.000000000000001
# 1  row sum =  0.9999999999999986
# 2  row sum =  1.0000000000000009
# 3  row sum =  0.9999999999999991
# 0  column sum =  0.999999999999998
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999994
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  103
#  - Current Loss =  177.40162511933
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999989
# 1  row sum =  1.0000000000000013
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999994
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  104
#  - Current Loss =  328.7874255191907
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999988
# 1  row sum =  1.000000000000001
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.0000000000000002
# 0  column sum =  0.9999999999999981
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999993
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  105
#  - Current Loss =  327.60021139736773
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.000000000000001
# 1  row sum =  0.9999999999999989
# 2  row sum =  1.0000000000000009
# 3  row sum =  0.999999999999999
# 0  column sum =  0.9999999999999991
# 1  column sum =  1.0000000000000018
# 2  column sum =  0.9999999999999992
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  106
#  - Current Loss =  186.78277915785293
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999981
# 1  row sum =  1.000000000000002
# 2  row sum =  0.9999999999999993
# 3  row sum =  1.0000000000000002
# 0  column sum =  0.9999999999999983
# 1  column sum =  1.000000000000003
# 2  column sum =  0.999999999999998
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  107
#  - Current Loss =  323.03876317453296
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  1.0000000000000007
# 2  row sum =  0.9999999999999999
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999977
# 1  column sum =  1.0000000000000016
# 2  column sum =  0.9999999999999996
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  108
#  - Current Loss =  317.96013358826144
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.000000000000001
# 1  row sum =  0.9999999999999993
# 2  row sum =  1.0000000000000004
# 3  row sum =  0.9999999999999992
# 0  column sum =  0.9999999999999988
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999984
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  109
#  - Current Loss =  207.97685121159748
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000009
# 1  row sum =  0.9999999999999992
# 2  row sum =  1.0000000000000004
# 3  row sum =  0.9999999999999996
# 0  column sum =  0.9999999999999986
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999989
# 3  column sum =  0.9999999999999998
#  -- Adam Optimization -- Step t =  110
#  - Current Loss =  206.84629648663326
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000007
# 1  row sum =  0.9999999999999989
# 2  row sum =  1.0000000000000013
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.9999999999999981
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999982
# 3  column sum =  1.0000000000000009
#  -- Adam Optimization -- Step t =  111
#  - Current Loss =  207.2718816099034
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.000000000000001
# 1  row sum =  0.999999999999999
# 2  row sum =  1.0000000000000007
# 3  row sum =  0.9999999999999996
# 0  column sum =  0.9999999999999989
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999989
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  112
#  - Current Loss =  204.50714496239993
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000027
# 1  row sum =  0.9999999999999982
# 2  row sum =  1.0000000000000002
# 3  row sum =  0.9999999999999987
# 0  column sum =  0.9999999999999989
# 1  column sum =  1.0000000000000018
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  113
#  - Current Loss =  211.5815595487577
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.000000000000002
# 1  row sum =  0.9999999999999983
# 2  row sum =  1.0000000000000009
# 3  row sum =  0.9999999999999992
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.0000000000000018
# 2  column sum =  1.0
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  114
#  - Current Loss =  214.92597398810744
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000007
# 1  row sum =  0.9999999999999988
# 2  row sum =  1.0000000000000018
# 3  row sum =  0.9999999999999992
# 0  column sum =  0.9999999999999979
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000009
#  -- Adam Optimization -- Step t =  115
#  - Current Loss =  213.58856431916684
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000007
# 1  row sum =  0.9999999999999986
# 2  row sum =  1.0000000000000013
# 3  row sum =  0.9999999999999997
# 0  column sum =  0.9999999999999981
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999984
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  116
#  - Current Loss =  220.61664111340542
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000007
# 1  row sum =  0.9999999999999986
# 2  row sum =  1.0000000000000013
# 3  row sum =  0.9999999999999997
# 0  column sum =  0.9999999999999981
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999984
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  117
#  - Current Loss =  220.61664111340542
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.000000000000001
# 1  row sum =  0.9999999999999979
# 2  row sum =  1.0000000000000013
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999973
# 1  column sum =  1.0000000000000033
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  118
#  - Current Loss =  226.73486938623864
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000016
# 1  row sum =  0.9999999999999983
# 2  row sum =  1.0000000000000018
# 3  row sum =  0.9999999999999987
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.000000000000003
# 2  column sum =  0.9999999999999989
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  119
#  - Current Loss =  228.13486043450735
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.000000000000001
# 1  row sum =  0.9999999999999991
# 2  row sum =  1.0000000000000013
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999993
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  120
#  - Current Loss =  230.7565674787743
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000013
# 1  row sum =  0.9999999999999986
# 2  row sum =  1.0000000000000009
# 3  row sum =  0.9999999999999987
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  121
#  - Current Loss =  234.82881794395053
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000029
# 1  row sum =  0.999999999999998
# 2  row sum =  1.0000000000000002
# 3  row sum =  0.9999999999999989
# 0  column sum =  0.9999999999999986
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999989
# 3  column sum =  0.9999999999999998
#  -- Adam Optimization -- Step t =  122
#  - Current Loss =  240.5396354025968
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.000000000000001
# 1  row sum =  0.9999999999999989
# 2  row sum =  1.0000000000000009
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.9999999999999983
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999982
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  123
#  - Current Loss =  241.77352433140118
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000007
# 1  row sum =  0.9999999999999991
# 2  row sum =  1.0000000000000007
# 3  row sum =  0.9999999999999991
# 0  column sum =  0.999999999999999
# 1  column sum =  1.0000000000000016
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  124
#  - Current Loss =  244.82021695664525
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000016
# 1  row sum =  0.9999999999999988
# 2  row sum =  1.0000000000000004
# 3  row sum =  0.9999999999999988
# 0  column sum =  0.9999999999999986
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999989
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  125
#  - Current Loss =  241.55409287148586
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000016
# 1  row sum =  0.9999999999999978
# 2  row sum =  1.000000000000001
# 3  row sum =  0.9999999999999991
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  126
#  - Current Loss =  246.80937654925515
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000027
# 1  row sum =  0.9999999999999981
# 2  row sum =  1.0000000000000009
# 3  row sum =  0.9999999999999987
# 0  column sum =  0.9999999999999988
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999989
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  127
#  - Current Loss =  254.17672744834294
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000018
# 1  row sum =  0.9999999999999977
# 2  row sum =  1.000000000000001
# ...
#  -- Adam Optimization -- Step t =  159
#  - Current Loss =  371.37950501178807
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999983
# 1  row sum =  1.0000000000000004
# 2  row sum =  0.9999999999999998
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999983
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  160
#  - Current Loss =  371.3754671770173
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999988
# 1  row sum =  1.0000000000000007
# 2  row sum =  1.0
# 3  row sum =  1.0000000000000007
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  161
#  - Current Loss =  371.0482277359665
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.999999999999998
# 1  row sum =  1.0000000000000013
# 2  row sum =  1.0000000000000004
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999997
# 1  column sum =  1.0000000000000013
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  162
#  - Current Loss =  370.8124384604173
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999978
# 1  row sum =  1.0000000000000018
# 2  row sum =  1.0
# 3  row sum =  1.0000000000000007
# 0  column sum =  0.999999999999999
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999984
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  163
#  - Current Loss =  369.85979720233627
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999984
# 1  row sum =  1.000000000000001
# 2  row sum =  0.9999999999999998
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999989
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  164
#  - Current Loss =  370.1205540831488
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999984
# 1  row sum =  1.0000000000000018
# 2  row sum =  0.9999999999999994
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.0000000000000036
# 2  column sum =  0.9999999999999988
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  165
#  - Current Loss =  370.0411518507326
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999988
# 1  row sum =  1.0000000000000004
# 2  row sum =  0.9999999999999996
# 3  row sum =  1.0000000000000007
# 0  column sum =  0.9999999999999976
# 1  column sum =  1.0000000000000036
# 2  column sum =  0.9999999999999988
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  166
#  - Current Loss =  369.61329755519364
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.999999999999998
# 1  row sum =  1.0000000000000016
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999991
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  167
#  - Current Loss =  54.75529926634772
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999991
# 1  row sum =  1.0000000000000009
# 2  row sum =  0.9999999999999994
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999979
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999994
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  168
#  - Current Loss =  370.3655688571739
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999979
# 1  row sum =  1.000000000000001
# 2  row sum =  1.0000000000000004
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999983
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  169
#  - Current Loss =  370.6525722304516
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999986
# 1  row sum =  1.0000000000000009
# 2  row sum =  0.9999999999999998
# 3  row sum =  1.0000000000000007
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.000000000000003
# 2  column sum =  0.9999999999999986
# 3  column sum =  0.9999999999999998
#  -- Adam Optimization -- Step t =  170
#  - Current Loss =  370.9810914484676
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999996
# 1  row sum =  1.0000000000000004
# 2  row sum =  0.9999999999999991
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999997
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  171
#  - Current Loss =  370.404353563918
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999986
# 1  row sum =  1.000000000000001
# 2  row sum =  0.9999999999999998
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  172
#  - Current Loss =  370.589886901638
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999996
# 1  row sum =  1.0000000000000002
# 2  row sum =  0.9999999999999992
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999992
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  173
#  - Current Loss =  369.5070235427429
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999979
# 1  row sum =  1.0000000000000013
# 2  row sum =  0.9999999999999996
# 3  row sum =  1.0000000000000013
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.000000000000003
# 2  column sum =  0.9999999999999984
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  174
#  - Current Loss =  369.2412813196165
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999989
# 1  row sum =  1.0000000000000009
# 2  row sum =  0.9999999999999996
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  175
#  - Current Loss =  368.5197996714353
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999988
# 1  row sum =  1.0000000000000004
# 2  row sum =  1.0
# 3  row sum =  1.0000000000000004
# 0  column sum =  0.9999999999999973
# 1  column sum =  1.000000000000003
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  176
#  - Current Loss =  369.18310001107943
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999986
# 1  row sum =  1.0000000000000013
# 2  row sum =  0.9999999999999991
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999993
# 1  column sum =  1.000000000000001
# 2  column sum =  0.9999999999999992
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  177
#  - Current Loss =  369.02492041537243
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.999999999999998
# 1  row sum =  1.000000000000001
# 2  row sum =  0.9999999999999999
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999989
# 1  column sum =  1.0000000000000018
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  178
#  - Current Loss =  369.1232123435377
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999988
# 1  row sum =  1.0000000000000009
# 2  row sum =  0.9999999999999998
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999986
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.999999999999999
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  179
#  - Current Loss =  368.54978710154364
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999989
# 1  row sum =  1.0000000000000009
# 2  row sum =  0.9999999999999996
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999994
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  180
#  - Current Loss =  368.10071897518424
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999989
# 1  row sum =  1.0000000000000009
# 2  row sum =  0.9999999999999996
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999994
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  181
#  - Current Loss =  368.10071897518424
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999987
# 1  row sum =  1.000000000000001
# 2  row sum =  0.999999999999999
# 3  row sum =  1.0000000000000009
# 0  column sum =  0.9999999999999992
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999989
# 3  column sum =  0.9999999999999998
#  -- Adam Optimization -- Step t =  182
#  - Current Loss =  368.76044678633025
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000016
# 1  row sum =  0.9999999999999982
# 2  row sum =  0.9999999999999998
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000018
# 2  column sum =  0.9999999999999992
# 3  column sum =  0.9999999999999998
#  -- Adam Optimization -- Step t =  183
#  - Current Loss =  254.0756274332664
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000013
# 1  row sum =  0.9999999999999989
# 2  row sum =  1.0
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999994
# 3  column sum =  1.0000000000000007
#  -- Adam Optimization -- Step t =  184
#  - Current Loss =  509.29292536253786
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000024
# 1  row sum =  0.9999999999999977
# 2  row sum =  1.0000000000000002
# 3  row sum =  1.0
# 0  column sum =  0.9999999999999987
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999981
# 3  column sum =  1.0000000000000009
#  -- Adam Optimization -- Step t =  185
#  - Current Loss =  510.9188351914497
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000029
# 1  row sum =  0.9999999999999977
# 2  row sum =  0.9999999999999998
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000033
# 2  column sum =  0.9999999999999981
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  186
#  - Current Loss =  511.66609222669956
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000016
# 1  row sum =  0.9999999999999979
# 2  row sum =  1.0000000000000009
# 3  row sum =  0.9999999999999991
# 0  column sum =  0.9999999999999982
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999991
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  187
#  - Current Loss =  253.15356818658006
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000002
# 1  row sum =  0.9999999999999989
# 2  row sum =  1.0000000000000007
# 3  row sum =  1.0
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999987
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  188
#  - Current Loss =  254.98273820751388
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000027
# 1  row sum =  0.9999999999999978
# 2  row sum =  0.9999999999999998
# 3  row sum =  0.9999999999999994
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.0000000000000033
# 2  column sum =  0.9999999999999983
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  189
#  - Current Loss =  511.26287144362857
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.000000000000001
# 1  row sum =  0.9999999999999983
# 2  row sum =  1.0000000000000016
# 3  row sum =  0.9999999999999996
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.0000000000000027
# 2  column sum =  0.9999999999999989
# 3  column sum =  1.0000000000000009
#  -- Adam Optimization -- Step t =  190
#  - Current Loss =  254.16767928035893
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000004
# 1  row sum =  0.9999999999999983
# 2  row sum =  1.0000000000000018
# 3  row sum =  0.999999999999999
# 0  column sum =  0.9999999999999979
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999982
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  191
#  - Current Loss =  256.05532251193563
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000018
# 1  row sum =  0.9999999999999988
# 2  row sum =  0.9999999999999998
# 3  row sum =  0.9999999999999998
# 0  column sum =  0.9999999999999981
# 1  column sum =  1.0000000000000022
# 2  column sum =  0.9999999999999992
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  192
#  - Current Loss =  513.3606788119164
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999979
# 1  row sum =  1.0000000000000013
# 2  row sum =  1.0
# 3  row sum =  1.0000000000000007
# 0  column sum =  0.9999999999999988
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999984
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  193
#  - Current Loss =  372.08003385223674
#  >>>>> Check double stoc of IP:
# 0  row sum =  0.9999999999999979
# 1  row sum =  1.0000000000000013
# 2  row sum =  1.0
# 3  row sum =  1.0000000000000007
# 0  column sum =  0.9999999999999988
# 1  column sum =  1.0000000000000024
# 2  column sum =  0.9999999999999984
# 3  column sum =  1.0000000000000004
#  -- Adam Optimization -- Step t =  194
#  - Current Loss =  372.08003385223674
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000004
# 1  row sum =  0.9999999999999988
# 2  row sum =  1.0000000000000009
# 3  row sum =  0.9999999999999996
# 0  column sum =  0.9999999999999984
# 1  column sum =  1.000000000000003
# 2  column sum =  0.999999999999998
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  195
#  - Current Loss =  258.67953283066527
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000016
# 1  row sum =  0.9999999999999989
# 2  row sum =  1.0000000000000004
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.9999999999999989
# 1  column sum =  1.0000000000000033
# 2  column sum =  0.9999999999999979
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  196
#  - Current Loss =  256.07707187500455
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000016
# 1  row sum =  0.9999999999999989
# 2  row sum =  1.0000000000000004
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.9999999999999989
# 1  column sum =  1.0000000000000033
# 2  column sum =  0.9999999999999979
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  197
#  - Current Loss =  256.07707187500455
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000016
# 1  row sum =  0.999999999999999
# 2  row sum =  1.0
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.9999999999999991
# 1  column sum =  1.000000000000002
# 2  column sum =  0.9999999999999988
# 3  column sum =  1.0000000000000002
#  -- Adam Optimization -- Step t =  198
#  - Current Loss =  252.73393156177326
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.000000000000001
# 1  row sum =  0.9999999999999996
# 2  row sum =  1.0000000000000004
# 3  row sum =  0.9999999999999994
# 0  column sum =  0.9999999999999998
# 1  column sum =  1.0000000000000013
# 2  column sum =  0.9999999999999993
# 3  column sum =  0.9999999999999999
#  -- Adam Optimization -- Step t =  199
#  - Current Loss =  250.99677448925422
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000047
# 1  row sum =  0.9999999999999966
# 2  row sum =  0.9999999999999991
# 3  row sum =  0.9999999999999996
# 0  column sum =  0.9999999999999978
# 1  column sum =  1.0000000000000047
# 2  column sum =  0.9999999999999971
# 3  column sum =  1.0
#  -- Adam Optimization -- Step t =  200
#  - Current Loss =  510.42463127691065
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000022
# 1  row sum =  0.9999999999999976
# 2  row sum =  1.0000000000000007
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999991
# 3  column sum =  0.9999999999999999
# θ_opt =  [0.98810609 4.94885586 2.76299208 1.64446897 2.54517288 3.13485212
#  3.80502251 3.25725177 1.58167075]
# min Loss =  257.10524814571863

# %%
plt.plot(range(len(KL_history)),KL_history, marker='p')
plt.title("KL Loss During Training")
plt.xlabel("Epochs")
plt.ylabel("KL Loss")
plt.show()

plt.plot(range(len(TV_history)),TV_history, marker='p')
plt.title("TV Loss During Training")
plt.xlabel("Epochs")
plt.ylabel("TV")
plt.show()

# %%
xsamples, phat = ut.sample_circuit( backend, sampleshots, qc.bind_parameters({theta: theta_opt}))

print('Original samples probs, π = ', pi_vec)
print('Optimized probabilitites, p(θ)= ', phat)
# Out:
# Original samples probs, π =  [0.144      0.136      0.136      0.11733333 0.136      0.11733333
#  0.11733333 0.096     ]
# Optimized probabilitites, p(θ)=  [0.04  0.248 0.146 0.172 0.106 0.062 0.212 0.014]

# %%
xlabels = []
for j in range(2**nq):
    xlabels.append(ut.binstr_from_int(j,nq))

print(xlabels)

barWidth = 0.25
 
r1 = np.arange(len(pi_vec))
r2 = [x + barWidth for x in r1]
plt.bar(r1, pi_vec, color='#7f6d5f', width=barWidth, edgecolor='white', label='π')
plt.bar(r2, phat, color='#557f2d', width=barWidth, edgecolor='white', label='p(θ)')
plt.xticks([r + barWidth for r in range(len(pi_vec))], xlabels, rotation=45)
plt.legend()
plt.show()
# Out:
# ['000', '001', '010', '011', '100', '101', '110', '111']

# %%
#path = '/home/alb/Scrivania/Quantum/Projects/BornMachine/data/'
#np.savetxt(path+'KLTraining4qb400it_theta_opt.csv', theta_opt, delimiter=',')
#np.savetxt(path+'KLTraining4qb400it_KL_history.csv', KL_history, delimiter=',')
#np.savetxt(path+'KLTraining4qb400it_TV_history.csv', TV_history, delimiter=',')

# %%
def KL(p,q):
    kl = 0
    for x in range(len(p)):
        if p[x] > 0:
            kl += p[x]* np.log(p[x]/q[x])
    return(kl)

# %%
print(KL(phat,pi_vec))
# Out:
# 0.20639181958616898

# %%
Sigmap = ut.estimate_covariance_embedding(xsamples,kernel_params)
Sigmaq = ut.estimate_covariance_embedding(ysamples, kernel_params)

print(ut.entropy_relative(Sigmap,Sigmaq))
# Out:
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000022
# 1  row sum =  0.9999999999999976
# 2  row sum =  1.0000000000000007
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999991
# 3  column sum =  0.9999999999999999
# 257.10524814571863

# %%
rho = ut.estimate_covariance_embedding(xsamples,kernel_params)
print(rho)
print(np.trace(rho))
print(np.linalg.eig(rho))
sigma = ut.estimate_covariance_embedding(ysamples, kernel_params)
print(np.trace(sigma))
print(np.linalg.eig(sigma))
print('Pennylane KL: ', qml.math.relative_entropy(rho,sigma))
print('My KL: ', ut.entropy_relative(rho,sigma))
# Out:
# [[ 49.25  28.25   9.5   49.25]
#  [ 28.25  68.    23.25  68.  ]
#  [  9.5   23.25  62.    62.  ]
#  [ 49.25  68.    62.   125.  ]]
# 304.25
# (array([218.78725567,  49.31507546,   7.82028371,  28.32738515]), array([[-0.31271819, -0.53718845,  0.42816169,  0.65598283],
#        [-0.45253484, -0.3736488 ,  0.33207554, -0.73846098],
#        [-0.38010387,  0.75308919,  0.52942056,  0.08995329],
#        [-0.74359975,  0.06835073, -0.65277658,  0.12755514]]))
# 304.25
# (array([223.28667226,  15.84599997,  34.52977872,  30.58754905]), array([[-0.40450334, -0.46082655,  0.75765182, -0.22356132],
#        [-0.37776165, -0.4194022 , -0.61818893, -0.54702867],
#        [-0.40945151, -0.37429021, -0.20859251,  0.80544737],
#        [-0.72527418,  0.68676599,  0.01718509, -0.04510554]]))
# Pennylane KL:  14.221291861186728
#  >>>>> Check double stoc of IP:
# 0  row sum =  1.0000000000000022
# 1  row sum =  0.9999999999999976
# 2  row sum =  1.0000000000000007
# 3  row sum =  0.9999999999999993
# 0  column sum =  0.999999999999998
# 1  column sum =  1.0000000000000029
# 2  column sum =  0.9999999999999991
# 3  column sum =  0.9999999999999999
# My KL:  257.10524814571863

# %%
def estimate_covariance_embedding(samples, phi_params):
    d = len(phi_params)
    if(d-1 != samples.shape[1]):
        print('Estimate covariance embedding ERROR: Wrong Dimension!')
        return 0
    eta = np.diag(np.sqrt(phi_params))
    print(eta)
    sigma = np.zeros((d,d))
    for i in range(len(samples)):
        cvec = np.append( samples[i], 1 )
        sigma += eta @ np.outer(cvec,cvec) @ eta

    return sigma/len(samples)
# Out:
# array([0.25, 0.25, 0.25, 0.25])

# %%
rvals, rvecs = np.linalg.eig(rho)
rvals = np.real(rvals)
svals, svecs = np.linalg.eig(sigma)
svals = np.real(svals)
print(rvals,svals)

rr = rvals@np.log(rvals)
rs = rvals@np.log(svals)
print(rr,rs)

IP = abs(rvecs@np.conj(svecs).T)**2
print(-rvals@IP@np.log(svals))
# Out:
# [218.78725567  49.31507546   7.82028371  28.32738515] [223.28667226  15.84599997  34.52977872  30.58754905]
# 1481.8951440899737 1444.1493241814333
# -1224.789895944255
